# %% [markdown]
# <a href="https://colab.research.google.com/github/flora0110/sentence_prediction/blob/main/show_result.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

# %%
folder_path = "/content/drive/MyDrive/senior/LAB/LawCaseRetreiver/sentence_predict/"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open(folder_path+'forgery_factors/train_data_0506.json', 'r', encoding='utf-8') as f:
    train_data_0506 = json.load(f)

# %%
with open(folder_path+'forgery_factors/train_data_6500down.json', 'r', encoding='utf-8') as f:
    train_data_6500down = json.load(f)

# %%
with open(folder_path+'forgery_factors/train_data_split.json', 'r', encoding='utf-8') as f:
    train_data_split = json.load(f)

# %%
print(f'old_factors with A prompt\n: {train_data_0506[8]["old_factors with A prompt"]}')
print(f"--------------------------------")
print(f'old_factors with B prompt\n: {train_data_0506[8]["old_factors with B prompt"]}')
print(f"--------------------------------")
print(f'new_factors with A prompt\n: {train_data_0506[8]["new_factors with A prompt"]}')
print(f"--------------------------------")
print(f'new_factors with B prompt\n: {train_data_0506[8]["new_factors with B prompt"]}')
print(f"--------------------------------")
print(f"~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# Out:
# old_factors with A prompt
# :  1. 被告郭致祥、劉立仁、「張先生」、曾滿容、藍文泰涉嫌共同行使使公務員登載不實文書，以假結婚的方式使藍文泰來臺，並共同取得臺灣居留證。
# 2. 被告郭致祥否認犯罪，但證人曾滿容、藍文泰、劉立仁、「張先生」等人均供述犯罪事實，並提供犯罪證據。
# 3. 被告郭致祥、劉立仁、「張先生」、曾滿容、藍文泰等人涉嫌共同行使使公務員登載不實文書，以假結婚的方式使藍文泰來臺，並共同取得臺灣居留證。
# 4. 被告郭致祥、劉立仁、「張先生」、曾滿容、藍文泰等人涉嫌共同行使使公務員登載不實文書，以假結婚的方式使藍文泰來臺，並共同取得臺灣居留證。
# 5. 被告郭致祥、劉立仁、「張先生」、曾滿容、藍文泰等人涉嫌共同行使使公務員登載不實文書，以假結婚的方式使藍文泰來臺，並共同取得臺灣居留證。
# 6. 被告郭致祥、劉立仁、「張先生」、曾滿容、藍文泰等人涉嫌共同行使使公務員登載不實文書，以假結婚的方式使藍文泰來臺，並共同取得臺灣居留證。
# 7. 被告郭致祥、劉立仁、「張先生」、曾滿容、藍文泰等人涉嫌共同行使使公務員登載不實文書，以假結婚的方式使藍文泰來臺，並共同取得臺灣居留證。
# 8. 被告郭致祥、劉立仁、「張先生」、曾滿容、藍文泰等人涉嫌共同行使使公務員登載不實文書，以假結婚的方式使藍文泰來臺，並共同取得臺灣居留證。
# 9. 被告郭致祥、劉立仁、「張先生」、曾滿容、藍文泰等人涉嫌共同行使使公務員登載不實文書，以假結婚的方式使藍文泰來臺，並共同取得臺灣居留證。
# 10. 被告郭致祥、劉立仁、「張先生」、曾滿容、藍文泰等人涉嫌共同行使使公務員登載不實文書，以假結婚的方式使藍文泰來臺，並共同取得臺灣居留證。
# 11. 被告郭致祥、劉立仁、「張先生」、曾滿容、藍文泰等人涉嫌共同行使使公務員登載不實文書，以假結婚的方式使藍文泰來臺，並共同取得臺灣居留證。
# 12. 被告郭致祥、劉立仁、「張先生」、曾滿容、藍文泰等人涉嫌共同行使使公務員登載不實文書，以假結婚的方式使藍文泰來臺，並共同取得臺灣居留證。
# 13. 被告郭致祥、劉立仁、「張先生」、曾滿容、藍文泰等人涉嫌共同行使使公務員登載不實文書，以假結婚的方式使藍文泰來臺，並共同取得臺灣居留證。
# ...

# %%
print(f'old_factors with A prompt\n: {train_data_6500down[8]["old_factors with A prompt"]}')
print(f"--------------------------------")
print(f'old_factors with B prompt\n: {train_data_6500down[8]["old_factors with B prompt"]}')
print(f"--------------------------------")
print(f'new_factors with A prompt\n: {train_data_6500down[8]["new_factors with A prompt"]}')
print(f"--------------------------------")
print(f'new_factors with B prompt\n: {train_data_6500down[8]["new_factors with B prompt"]}')
print(f"--------------------------------")
print(f"~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# Out:
# old_factors with A prompt
# :  1.犯罪手段：被告郭致祥、劉立仁、「張先生」、曾滿容、藍文泰共同以假結婚之方式使無結婚真意之藍文泰來臺工作，並收取250,000元之報酬。
# 2.損害程度：本案造成戶政機關及主管機關對戶籍及身分管理之損害，影響臺灣社會秩序。
# 3.影響範圍：被告等人以假結婚方式使藍文泰來臺工作，並持相關文件以申請來臺簽證、居留證，使主管機關核發居留簽證、居留證，影響臺灣社會秩序。
# 4.犯罪類型：被告等人共同以假結婚方式使無結婚真意之藍文泰來臺工作，並持相關文件以申請來臺簽證、居留證。
# 5.偽造文件種類及使用方式：被告等人偽造結婚證明文件，並持以向戶政機關申辦虛偽之結婚登記，再持該等文件向駐泰國臺北經濟文化辦事處申請來臺簽證，以及向臺北縣警察局樹林分局外事課申辦居留證、展延居留證。
# 6.不詳人士之參與程度：被告等人以假結婚方式使藍文泰來臺工作，並持相關文件以申請來臺簽證、居留證，影響臺灣社會秩序。
# 7.偽造手法不同：被告等人偽造結婚證明文件，並持以向戶政機關申辦虛偽之結婚登記，再持該等文件向駐泰國臺北經濟文化辦事處申請來臺簽證，以及向臺北縣警察局樹林分局外事課申辦居留證、展延居留證。
# 8.不詳人士的參與程度：被告等人以假結婚方式使藍文泰來臺工作，並持相關文件以申請來臺簽證、居留證，影響臺灣社會秩序。
# 9.偽造手法不同：被告等人偽造結婚證明文件，並持以向戶政機關申辦虛偽之結婚登記，再持該等文件向駐泰國臺北經濟文化辦事處申請來臺簽證，以及向臺北縣警察局樹林分局外事課申辦居留證、展延居留證。
# 10.犯罪後之態度：被告郭致祥否認犯罪，其餘被告則坦承犯罪。
# 11.犯罪動機與意圖：被告等人以假結婚方式使藍文泰來臺工作，並持相關文件以申請來臺簽證、居留證，影響臺灣社會秩序。
# 12.被害人與金額：藍文泰為被害人，被告等人持偽造之文件向主管機關申請來臺簽證、居留證，影響臺灣社會秩序。
# 13.被告關係：被告等人共同以假結婚方式使藍文泰來臺工作，並持相關文件以申請來臺簽證、居留證，影響臺灣社會秩序。
# ...

# %%
print(f'old_factors with A prompt\n: {train_data_split[8]["old_factors with A prompt"]}')
print(f"--------------------------------")
print(f'old_factors with B prompt\n: {train_data_split[8]["old_factors with B prompt"]}')
print(f"--------------------------------")
print(f'new_factors with A prompt\n: {train_data_split[8]["new_factors with A prompt"]}')
print(f"--------------------------------")
print(f'new_factors with B prompt\n: {train_data_split[8]["new_factors with B prompt"]}')
print(f"--------------------------------")
print(f"~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# Out:
# old_factors with A prompt
# :  1.犯罪手段：被告郭致祥、劉立仁、「張先生」、曾滿容、藍文泰共同以假結婚之方式使無結婚真意之藍文泰來臺工作，並收取250,000元之報酬。
# 2.損害程度：本案造成戶政機關、駐泰國臺北經濟文化辦事處、臺北縣警察局樹林分局外事課等主管機關之文書登載不實，影響戶政機關、戶籍及身分管理之正確性，並使藍文泰等人得以非法來臺工作。
# 3.影響範圍：本案影響範圍包括泰國籍勞工來臺工作之管理、臺灣的戶籍及身分管理，以及主管機關對居留簽證、居留證之核發。
# 4.犯罪手法：被告等人先由劉立仁前往泰國，再安排曾滿容前往泰國，辦理結婚手續，並持結婚文件向駐泰國臺北經濟文化辦事處取得認證後，再返回臺灣。
# 5.詐取金額：被告等人收取250,000元之報酬。
# 6.影響的範圍：本案影響範圍包括泰國籍勞工來臺工作之管理、臺灣的戶籍及身分管理，以及主管機關對居留簽證、居留證之核發。
# 7.犯罪動機和意圖：被告等人之犯罪動機和意圖為謀取報酬，並使藍文泰等人得以非法來臺工作。
# 8.不詳人士的參與程度：被告等人的共犯曾滿容、藍文泰、劉立仁、「張先生」、劉立仁等人均已到案，但可能仍有不詳人士參與本案，例如藍文泰在泰國的仲介。
# 9.偽造文件的種類：本案涉及偽造之文件包括結婚證明、戶籍謄本、國民身分證等。
# 10.偽造手法：被告等人偽造文件之手法為在泰國辦理結婚手續，並持結婚文件向駐泰國臺北經濟文化辦事處取得認證後，再返回臺灣。
# 11.指紋比對：本案涉及指紋比對，以確認曾滿容、藍文泰等人之身分。
# 12.檢測日期：本案涉及曾滿容、藍文泰等人在泰國辦理結婚手續之日期。
# 13.車輛歸屬：本案涉及藍文泰等人來臺後，以車輛作為交通工具。
# 14.影響的範圍：本案影響範圍包括泰國籍勞工來臺工作之管理、臺灣的戶籍及身分管理，以及主管機關對居留簽證、居留證之核發。
# 15.交易手法：被告等人以假結婚之方式使藍文泰等人來臺工作，並收取250,000元之報酬。
# 16.詐欺手法：被告等人以假結婚之方式使藍文泰等人來臺工作，並收取報酬。
# 17.監護人：本案涉及藍文泰等人之監護人。
# 18.前科記錄：被告等人之犯罪前科記錄。
# 19.行為主體：本案涉及被告郭致祥、劉立仁、曾滿容、藍文泰、「張先生」等人。
# ...

# %%
i=0
for item in train_data_0506[:20]:
  print(i)
  i = i+1
  print(f'old_factors with A prompt\n: {item["old_factors with A prompt"]}')
  print(f"--------------------------------")
  print(f'old_factors with B prompt\n: {item["old_factors with B prompt"]}')
  print(f"--------------------------------")
  print(f'new_factors with A prompt\n: {item["new_factors with A prompt"]}')
  print(f"--------------------------------")
  print(f'new_factors with B prompt\n: {item["new_factors with B prompt"]}')
  print(f"--------------------------------")
  print(f"~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# Out:
# 0
# old_factors with A prompt
# :  1. 中華民國刑法第214條（使公務員登載不實罪）：明知為不實之事項，而使公務員登載於職務上所掌之公文書，足以生損害於公眾或他人者，處3年以下有期徒刑、拘役或5百元以下罰金。
# 2. 中華民國刑法第216條（行使偽造變造或登載不實之文書罪）：行使第210條至第215條之文書者，依偽造、變造、登載不實或行使偽造變造之文書論。
# --------------------------------
# old_factors with B prompt
# :  1. 隱含要件項目：
#
# a. 犯罪手段：被告與共犯林清水、詹巧薇等人共同利用假結婚的方式，以便讓被告與陳玉婉取得居留權。
# b. 犯罪動機和意圖：被告和共犯林清水、詹巧薇等人為了賺取報酬，而安排被告與陳玉婉假結婚。
# c. 被害人和金額：被告和共犯陳玉婉利用偽造的戶籍謄本等資料，向臺南縣政府警察局外事課申請核發陳玉婉之外僑居留證及申請居留證延期。
# d. 損害程度：被告和共犯陳玉婉的行為可能導致戶政機關和主管機關對假結婚案件的管理和正確性受到損害。
# e. 影響範圍：被告和共犯陳玉婉的行為可能影響到臺灣的戶籍管理、假結婚案件的處理和外籍人士的居留管理。
# f. 犯罪手法：被告和共犯林清水、詹巧薇等人共同利用假結婚的方式，以便讓被告和陳玉婉取得居留權。
# g. 影響的範圍：被告和共犯陳玉婉的行為可能影響到戶政機關、主管機關和外籍人士的權益。
# h. 犯罪程度：被告和共犯陳玉婉的行為可能導致戶政機關和主管機關對假結婚案件的管理和正確性受到損害。
# i. 犯罪手段和程度：被告和共犯林清水、詹巧薇等人利用假結婚的方式，以便讓被告和陳玉婉取得居留權，可能導致戶政機關和主管機關對假結婚案件的管理和正確性受到損害。
# j. 犯罪動機和意圖：被告和共犯林清水、詹巧薇等人為了賺取報酬，而安排被告與陳玉婉假結婚。
# k. 損害程度：被告和共犯陳玉婉的行為可能導致戶政機關和主管機關對假結婚案件的管理和正確性受到損害。
# l. 影響範圍：被告和共犯陳玉婉的行為可能影響到戶政機關、主管機關和外籍人士的權益。
# m. 犯罪手法：被告和共犯林清水、詹巧薇等人利用假結婚的方式，以便讓被告和陳玉婉取得居留權。
# ...

# %%
i=0
for item in train_data_6500down:
  print(i)
  i = i+1
  print(f'old_factors with A prompt\n: {item["old_factors with A prompt"]}')
  print(f"--------------------------------")
  print(f'old_factors with B prompt\n: {item["old_factors with B prompt"]}')
  print(f"--------------------------------")
  print(f'new_factors with A prompt\n: {item["new_factors with A prompt"]}')
  print(f"--------------------------------")
  print(f'new_factors with B prompt\n: {item["new_factors with B prompt"]}')
  print(f"--------------------------------")
  print(f"~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# Out:
# 0
# old_factors with A prompt
# :
#
# 中華民國刑法第214條（使公務員登載不實罪）
# 明知為不實之事項，而使公務員登載於職務上所掌之公文書，足以生損害於公眾或他人者，處3年以下有期徒刑、拘役或5百元以下罰金。
#
# 中華民國刑法第216條（行使偽造變造或登載不實之文書罪）
# 行使第二百一十條至第二百一十五條之文書者，依偽造、變造文書或登載不實事項或偽變造印章、印文、印文、認証章之規定，處一年以下有期徒刑、拘役或新臺幣九千元以下罰金。
#
# 中華民國刑法第28條（共同正犯）
# 二人以上共同實行犯罪之行為者，皆為共同正犯。
#
# 中華民國刑法第214條（使公務員登載不實罪）
# 明知為不實之事項，而使公務員登載於職務上所掌之公文書，足以生損害於公眾或他人者，處3年以下有期徒刑、拘役或5百元以下罰金。
#
# 中華民國刑法第216條（行使偽造變造或登載不實之文書罪）
# 行使第二百一十條至第二百一十五條之文書者，依偽造、變造文書或登載不實事項或偽變造印章、印文、認証章之規定，處一年以下有期徒刑、拘役或新臺幣九千元以下罰金。
#
# 中華民國刑法第28條（共同正犯）
# 二人以上共同實行犯罪之行為者，皆為共同正犯。
# --------------------------------
# old_factors with B prompt
# :  本案涉及的犯罪行為、犯罪手法、犯罪程度、影響範圍、法律適用、涉及債權的性質不同、應訊時的自白情況不同、涉及當事人不同、犯罪手段、犯罪動機和意圖、犯罪手段的細節不同、指紋比對的結果不同、檢測日期的不同、車輛歸屬不同、影響的範圍不同、犯罪時間和地點、盜領款項數目和頻率、文書內容的真實性、貸款金額及償還行為、虛偽信託方式、人數及組織形式、銀行職員的警覺、變造文書程度不同、公司涉及、盜領之後的處理不同、受害者的數量和身份、信用卡的數量和使用情況、未經全體繼承人同意或授權、廢棄物種類、債權關係、不動產登記事項等。以下是根據上述項目整理的隱含要件項目：
#
# 1. 犯罪手段：被告與共犯林清水、詹巧薇、張晉源等人共同以假結婚的方式辦理結婚登記，以取得陳玉婉來臺居留權。
# 2. 犯罪動機和意圖：被告和共犯們為賺取報酬，而以假結婚的方式使陳玉婉取得來臺居留權。
# ...

# %%
i=0
for item in train_data_split:
  print(i)
  i = i+1
  print(f'old_factors with A prompt\n: {item["old_factors with A prompt"]}')
  print(f"--------------------------------")
  print(f'old_factors with B prompt\n: {item["old_factors with B prompt"]}')
  print(f"--------------------------------")
  print(f'new_factors with A prompt\n: {item["new_factors with A prompt"]}')
  print(f"--------------------------------")
  print(f'new_factors with B prompt\n: {item["new_factors with B prompt"]}')
  print(f"--------------------------------")
  print(f"~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# Out:
# 0
# old_factors with A prompt
# :  1.中華民國刑法第214條（使公務員登載不實罪）：
#
# 明知為不實之事項，而使公務員登載於職務上所掌之公文書，足以生損害於公眾或他人者，處三年以下有期徒刑、拘役或新臺幣九萬元以下罰金。
#
# 2.中華民國刑法第216條（行使偽造變造或登載不實之文書罪）：
#
# 行使第二百一十條至第二百一十五條之文書者，依偽造、變造文書或登載不實事項於公文書罪章規定處罰。
#
# 在本案中，被告陳泰龍涉嫌與共犯陳玉婉（泰國籍）、林清水、詹巧薇、張晉源等人共同基於行使使公務員登載不實公文書之概括犯意聯絡，先由被告依指示前往泰國辦理假結婚，再持經泰國公證之結婚登記書、結婚證書等文件，前往臺南縣永康市戶政事務所填寫結婚登記申請書，申請辦理其與陳玉婉之結婚登記，因此使上開戶政事務所僅有形式審查權之公務員陷於錯誤，於形式上審核後，將陳泰龍與陳玉婉於93年4月7日結婚之不實事項登載於其職務上所掌之戶籍登記資料內，並據以核發戶籍謄本，而足以生損害於戶政機關對於戶政管理及戶籍登記資料維護之正確性。
#
# 被告於本案中涉嫌行使使公務員登載不實之戶籍謄本等文件，因此適用中華民國刑法第214條使公務員登載不實罪。
#
# 中華民國刑法第214條（使公務員登載不實罪）
# 明知為不實之事項，而使公務員登載於職務上所掌之公文書，足以生損害於公眾或他人者，處3年以下有期徒刑、拘役或5百元以下罰金。
#
# 中華民國刑法第216條（行使偽造變造或登載不實之文書罪）
# 行使第二百一十條至第二百一十五條之文書者，依偽造、變造文書或登載不實事項或不正
# --------------------------------
# old_factors with B prompt
# :  本案涉及的犯罪手段、損害程度、影響範圍、法律適用、涉及債權的性質不同、應訊時的自白情況不同、涉及當事人不同、被涉案人的不同身份、涉及毒品的案件類型、偽造文件的種類和使用方式、不詳人士的參與程度、犯罪手段細節不同、指紋比對的結果不同、檢測日期的不同、車輛歸屬不同、影響的範圍不同、交易手法不同、詐欺對象不同、監護人身份、前科記錄、行為主體、犯罪手段和程度、犯罪動機和意圖、涉及的被害人和金額等。以下是根據上述項目整理的內容：
#
# ...
